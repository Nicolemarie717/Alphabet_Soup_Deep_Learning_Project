# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# C:\Users\nicol\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
application_df = application_df.drop(['EIN', 'NAME'], axis=1)

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
# taking 400 as the cut off value, so bins lesser than 400 will be replaced
application_types_to_replace = ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
application_df['CLASSIFICATION'].value_counts().loc[lambda x: x > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE

# choosing cutoff of 1000
classifications_to_replace = application_df['CLASSIFICATION'].value_counts().loc[lambda x: x < 1000].index
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
# Check for all object type column and automatically convert them to numerical with `pd.dummies`

application_df_1 = application_df.copy()
for column in application_df_1.columns:
    if application_df_1[column].dtype == 'object':
        application_df_1 = pd.get_dummies(application_df_1, columns=[column])

application_df_1
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# ...

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
features = application_df_1.drop('IS_SUCCESSFUL', axis=1)
target = application_df_1['IS_SUCCESSFUL']
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=21, test_size=0.2)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation='relu', input_shape=(X_train_scaled.shape[1],)))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))  # Use 'linear' activation for regression tasks

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# ...
# Total params: 5981 (23.36 KB)
# Trainable params: 5981 (23.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss='binary_crossentropy',
           optimizer='adam',
           metrics=['accuracy'])

# %%
# Train the model
#  YOUR CODE GOES HERE
nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 858/858 [==============================] - 2s 1ms/step - loss: 0.5753 - accuracy: 0.7145
# Epoch 2/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5577 - accuracy: 0.7252
# Epoch 3/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5543 - accuracy: 0.7277
# Epoch 4/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5530 - accuracy: 0.7296
# Epoch 5/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5516 - accuracy: 0.7286
# Epoch 6/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5511 - accuracy: 0.7302
# Epoch 7/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5496 - accuracy: 0.7299
# Epoch 8/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5493 - accuracy: 0.7310
# Epoch 9/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5486 - accuracy: 0.7310
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 215/215 - 1s - loss: 0.5514 - accuracy: 0.7370 - 599ms/epoch - 3ms/step
# Loss: 0.551355242729187, Accuracy: 0.7370262145996094

# %% [markdown]
# ## Optimization Attempt 1

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()
input_shape = X_train_scaled.shape[1]
# First hidden layer
nn.add(tf.keras.layers.Dense(units=128, activation='relu', input_shape=(X_train_scaled.shape[1],)))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=64, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=32, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))  # Use 'linear' activation for regression tasks

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 128)               5632
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dense_6 (Dense)             (None, 1)                 33
#
# ...
# Total params: 16001 (62.50 KB)
# Trainable params: 16001 (62.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss='binary_crossentropy',
           optimizer='sgd',
           metrics=['accuracy'])

# %%
# Train the model
#  YOUR CODE GOES HERE
nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5978 - accuracy: 0.7092
# Epoch 2/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5648 - accuracy: 0.7235
# Epoch 3/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5598 - accuracy: 0.7272
# Epoch 4/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5567 - accuracy: 0.7282
# Epoch 5/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5551 - accuracy: 0.7279
# Epoch 6/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5537 - accuracy: 0.7287
# Epoch 7/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5523 - accuracy: 0.7286
# Epoch 8/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7298
# Epoch 9/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5506 - accuracy: 0.7302
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 215/215 - 0s - loss: 0.5443 - accuracy: 0.7378 - 281ms/epoch - 1ms/step
# Loss: 0.5443081259727478, Accuracy: 0.7377551198005676

# %% [markdown]
# ## Optimization Attempt 2

# %%
nn = tf.keras.models.Sequential()

# First hidden layer with dropout
nn.add(tf.keras.layers.Dense(units=256, activation='relu', input_shape=(input_shape,)))
nn.add(tf.keras.layers.Dropout(0.2))

# Second hidden layer with dropout
nn.add(tf.keras.layers.Dense(units=128, activation='tanh'))
nn.add(tf.keras.layers.Dropout(0.2))

# Output layer (for binary classification)
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Compile the model
nn.compile(loss='binary_crossentropy',
           optimizer='adam',
           metrics=['accuracy'])

# Check the updated structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 256)               11264
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_8 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 1)                 129
#
# ...
# Total params: 44289 (173.00 KB)
# Trainable params: 44289 (173.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss='binary_crossentropy',
           optimizer='adam',
           metrics=['accuracy'])

# %%
# Train the model
#  YOUR CODE GOES HERE
nn.fit(X_train_scaled, y_train, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 858/858 [==============================] - 3s 2ms/step - loss: 0.5831 - accuracy: 0.7104
# Epoch 2/50
# 858/858 [==============================] - 3s 3ms/step - loss: 0.5662 - accuracy: 0.7228
# Epoch 3/50
# 858/858 [==============================] - 2s 3ms/step - loss: 0.5626 - accuracy: 0.7247
# Epoch 4/50
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5597 - accuracy: 0.7271
# Epoch 5/50
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5577 - accuracy: 0.7276
# Epoch 6/50
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5574 - accuracy: 0.7270
# Epoch 7/50
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5562 - accuracy: 0.7269
# Epoch 8/50
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5555 - accuracy: 0.7291
# Epoch 9/50
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5553 - accuracy: 0.7290
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 215/215 - 1s - loss: 0.5428 - accuracy: 0.7366 - 590ms/epoch - 3ms/step
# Loss: 0.5427504181861877, Accuracy: 0.7365888953208923

# %% [markdown]
# ## Optimization Attempt 3

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
# Check for all object type column and automatically convert them to numerical with `pd.dummies`
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

application_df_2 = application_df.copy()
for column in application_df_2.columns:
    if application_df_2[column].dtype == 'object':
        application_df_2[column] = label_encoder.fit_transform(application_df_2[column])

application_df_2
# Out:
#        APPLICATION_TYPE  AFFILIATION  CLASSIFICATION  USE_CASE  ORGANIZATION  \
# 0                     1            2               0         4             0
# 1                     3            2               2         3             1
# 2                     5            0               4         4             0
# 3                     3            0               2         3             3
# 4                     3            2               0         1             3
# ...                 ...          ...             ...       ...           ...
# 34294                 4            2               0         4             0
# 34295                 4            0               4         4             0
# 34296                 3            0               2         3             0
# 34297                 5            2               4         4             0
# 34298                 3            2               0         3             1
#
# ...

# %%
application_df_2.STATUS.nunique()
# Out:
# 2

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
features = application_df_2.drop('IS_SUCCESSFUL', axis=1)
target = application_df_2['IS_SUCCESSFUL']
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=21, test_size=0.2)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()
input_shape = X_train_scaled.shape[1]
# First hidden layer
nn.add(tf.keras.layers.Dense(units=64, activation='relu', input_shape=(X_train_scaled.shape[1],)))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=32, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=4, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))  # Use 'linear' activation for regression tasks

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 64)                640
#
#  dense_11 (Dense)            (None, 32)                2080
#
#  dense_12 (Dense)            (None, 4)                 132
#
#  dense_13 (Dense)            (None, 1)                 5
#
# ...
# Total params: 2857 (11.16 KB)
# Trainable params: 2857 (11.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss='binary_crossentropy',
           optimizer='adam',
           metrics=['accuracy'])

# %%
# Train the model
#  YOUR CODE GOES HERE
nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.6250 - accuracy: 0.6987
# Epoch 2/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5902 - accuracy: 0.7141
# Epoch 3/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5816 - accuracy: 0.7170
# Epoch 4/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5782 - accuracy: 0.7181
# Epoch 5/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5759 - accuracy: 0.7197
# Epoch 6/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5739 - accuracy: 0.7198
# Epoch 7/100
# 858/858 [==============================] - 2s 2ms/step - loss: 0.5725 - accuracy: 0.7212
# Epoch 8/100
# 858/858 [==============================] - 1s 2ms/step - loss: 0.5710 - accuracy: 0.7218
# Epoch 9/100
# 858/858 [==============================] - 1s 1ms/step - loss: 0.5698 - accuracy: 0.7221
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 215/215 - 0s - loss: 0.5481 - accuracy: 0.7363 - 364ms/epoch - 2ms/step
# Loss: 0.5480917096138, Accuracy: 0.7362973690032959

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save('AlphabetSoupCharity_Optimization.h5')
# Out:
# C:\Users\nicol\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
